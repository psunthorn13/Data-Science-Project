# %% [markdown]
# #  Assignment-2B-Task1_flight_producer: Producing the streaming data (30%)
#
# Name : Pichaphop Sunthornjittanon
#
# Student ID : 31258301

# %% [markdown]
# In this section, you will need to implement an Apache Kafka producer to simulate the
# real-time streaming of the data.
#
# Important:
#
# ● In this task, you need to generate the event timestamp in UTC timezone for each data
# record in the producer, and then convert the timestamp to unix-timestamp format
# (keeping UTC timezone) to simulate the “ts” column. For example, if the current time
# is 2021-9-28 12:39:45 UTC, it should be converted to the value of 1632796806, and
# stored in the “ts” column
#
# ● Please do not use Spark in this task

# %% [markdown]
# #### Event Flight Producer
#
# Write a python program that loads all the data from “flight*.csv”. Save the file as
# Assignment-2B-Task1_flight_producer.ipynb.
# Your program should send X number and Y number of records from each producer
# following the sequence to the Kafka stream every 5 seconds. X represents the records to
# send in a particular batch, whereas Y represents the records to send in the next batch (pending
# records). The sequence of the batch is depicted in Fig.1.
#
# There are some steps need to be carried out for this task:
#
# 1. Generate random numbers A and B, whose values are between 70-100 (inclusive) and
# 5-10 (inclusive) respectively, which are regenerated for each keyFlight. The
# keyFlights are generated from the column ‘DAY_OF_WEEK’ in the dataset which has
# 7 unique keys. These values 1, 2, 3, 4, 5, 6, and, 7 represents ‘sunday’,‘monday’,
# ‘tuesday’, ‘wednesday’,’thursday’,’friday’,’saturday’
# 2. You will need to append event time in unix-timestamp format (as mentioned above)
# for each key. Assuming that there are 7 keys in the flight-dataset as mentioned above,
# there will be 7 unix-timestamp for each batch.
# 3. Each batch data contains 7 group (7 sub batches) instances generated from each key.
# All of them are concatenated in the form of the list of dictionaries
#
# a. Explanation of a group instances/records
#
#
# i. If A1 represents a group of instances/records generated from key = ‘1’
# and B1 represents a group of pending instances/records generated from
# key = ‘1’, thus batch 1 (X1) contains [A1; A2; A3; A4; A5; A6; A7] and
# batch 1 pending (Y1) contains [B1; B2; B3; B4; B5; B6; B7].
#
# ii. A1 and B1 have the same ‘ts’ as it is generated from the same batch atthe same time. The same case is also the same for A2 and B2 and so on.
#
# iii. Given random numbers A and B, the number of instances in A1, A2 and
# B1, B2 and so on vary
#
# b. Explanation of a dictionary.
# Dictionary represents an instance of data which output can be seen as follow
#
#
# i. Example of a dictionary with key = ‘1’ {‘ts’:1632796806,..,
# ‘DAY_OF_WEEK’:1, ‘month’:1,...}
#
# ii. Example of a dictionary with key = ‘7’ {‘ts’:1632744322,...,
# ‘DAY_OF_WEEK’:7, ‘month’:3,...}
#
# iii. Dictionary is a part of a sub batch data. A sub batch data is a part of a
# batch data X. This also applies for pending data B.
#
# 4. Simulation of data stream in Fig.1.
#
# a. At time1: X1 and Y1 are generated on the producer side, but only X1 is sent.
#
# b. At time2: X2 and Y2 are generated on the producer side, but only X2 and
# pending data from the previous batch (Y1) are sent to the consumer.
#
#
# 5. If the data in each key is exhausted, restart from the first sequence again.
#
#
# 6. Pseudocode for this task:
#
# a. Take the DAY_OF_WEEK column as the key, name a variable KeyFlights
# which contains the set of keys (7 keys).
#
# b. Create a function getFlightRecords, which returns a variable named
# flightRecords, which is a dictionary that contains all flight data with their
# associated keys (step 3).
#
# c. Create a topic called ‘flightTopic’
#
# d. Create an instance variable called ‘flightProducer’
#
# e. for each keyFlight in KeyFlights
#
# i. Generate A[‘keyFlight’] and B[‘keyFlight’] and give both the
# timestamp as formatted in 3.b or Fig.2.
#
# ii. Concatenate all A and B. It will form the data batch X and Y
# respectively, see Fig.2.
#
# f. Send X and Y to the consumer following the rule in step 4 or Fig.1

# %%
# 1. Import libraries

from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
# import csv
import pandas as pd
import time

# %%
# 2. Load flight data to dataframe

# Initiate flight_df
flight_df = pd.DataFrame()

# Load all flight CSV file to dataframe
for number in range(1,21):
    
    # Load each file
    cur_file = pd.read_csv(f'data/flight{number}.csv')

    # Combine to the previous file
    flight_df = flight_df.append(cur_file)

# %%
# 2. Create useful functions

# Create publish_message function - publish data and print the size of data that's just sent
def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, data)
        print('Message published successfully. Data Size: ' + str(len(data)))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
# Create connect_kafka_producer function - configure kafka producer
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
# Create a function getFlightRecords, which returns a variable named flightRecords, 
# which is a dictionary that contains all flight data with their associated keys (Step B in the pseudocode)
def getFlightRecords(key) :
    flightRecords = flight_df[flight_df['DAY_OF_WEEK'] == key].to_dict(orient='records')
    
    return flightRecords

# %%
# 3.Write the code that follow pseudcode in 1.6 from specification

if __name__ == '__main__':

    # a. Take the DAY_OF_WEEK column as the key, name a variable KeyFlights which contains the set of keys (7 keys)
    KeyFlights = set(flight_df['DAY_OF_WEEK'])

    # b. Create a function getFlightRecords, which returns a variable named flightRecords, 
    # which is a dictionary that contains all flight data with their associated keys (Done in the previous section)

    # Use function getFlightRecords to get data of each associated keys flightRecords_1 - flightRecords_7 (list of dict)
    for keyFlight in KeyFlights :

        # Create flightRecord_1 - flightRecord_7 
        globals()['flightRecords_%s' % keyFlight]  = getFlightRecords(keyFlight)

    # c. Create a topic called ‘flightTopic
    topic_name = 'flightTopic'

    # d. Create an instance variable called ‘flightProducer’
    flightProducer = connect_kafka_producer()

    # e.

    # Initialise time t
    t = 1

    while True :

        # e. for each keyFlight in KeyFlights
        for keyFlight in KeyFlights :

            # Generate event unix-timestamp (UTC timezone)
            ts = int(dt.datetime.utcnow().timestamp())

            ############################################## For An ##############################################


            # Generate random number A between 70-100(inclusive)
            num_A = random.randint(70,100)    
            
            # Create stream_data that stores data that we want to put to An 
            stream_data = globals()['flightRecords_%s' % keyFlight][0:num_A]
            
            ########### This is a process of selecting flight data in sequence and reusing data once it is exhausted ####
            # Remove the stream data from the flight record in each key
            globals()['flightRecords_%s' % keyFlight] = globals()['flightRecords_%s' % keyFlight][num_A:
                                                                len(globals()['flightRecords_%s' % keyFlight])]
            
            # Append them back to the end of the list
    
            globals()['flightRecords_%s' % keyFlight].extend(stream_data)

            ###########
            
            # Create An variable that contains stream data that we want to send
            globals()['A%s' % keyFlight] = stream_data
            

            # Add timestamp to An
            for index in range(0,len(globals()['A%s' % keyFlight])) :
                globals()['A%s' % keyFlight][index]['ts'] = ts

            ####################################################################################################
            
            ############################################## For Bn ##############################################

            # Generate random number B between 5-10(inclusive)
            num_B = random.randint(5,10)

            # Create stream_data that stores data that we want to put to Bn
            stream_data = globals()['flightRecords_%s' % keyFlight][0:num_B]
            
            ########### This is a process of selecting flight data in sequence and reusing data once it is exhausted ####
            
            # Remove the stream data from the flight record in each key
            globals()['flightRecords_%s' % keyFlight] = globals()['flightRecords_%s' % keyFlight][num_B:
                                                                                len(globals()['flightRecords_%s' % keyFlight])]    
    

    
            # Append them back to the end of the list
            globals()['flightRecords_%s' % keyFlight].extend(stream_data)

            ###########
            
            # Create Bn variable that contains stream data that we want to send
            globals()['B%s' % keyFlight] = stream_data
    

            # Add timestamp to B
            for index in range(0,len(globals()['B%s' % keyFlight])) :
                globals()['B%s' % keyFlight][index]['ts'] = ts
            
            sleep(1)
            
            ####################################################################################################

        # Concate A1-A7 to get Xt
        X = []
        X.extend(A1)
        X.extend(A2)
        X.extend(A3)
        X.extend(A4)
        X.extend(A5)
        X.extend(A6)
        X.extend(A7)

        # Concate B1-B7 to get Yt
        Y = []
        Y.extend(B1)
        Y.extend(B2)
        Y.extend(B3)
        Y.extend(B4)
        Y.extend(B5)
        Y.extend(B6)
        Y.extend(B7)

        print(f'\n################ T{t} ################')

        print(f'\n### Unix Timestamp : {ts} ###')

        # If t=1
        if t == 1 :

            print(f'X{t}',' : Data size =', len(X))

            # Publish only X1
            publish_message(flightProducer, topic_name, X)

        # If time is greater than 1
        else :

            print(f'X{t}',' : Data size =', len(X))
            print(f'Y{t-1}',' : Data size =', len(Y_previous))

            # Concat Xt and Yt-1
            flight_data = X+Y_previous

            # Publish Xt and Yt-1
            publish_message(flightProducer, topic_name, flight_data)

        # Store Y_previous with Yt
        Y_previous = Y.copy()

        # Increase time by 1
        t += 1

        # send X number and Y number of records every 5 seconds
        sleep(3)
# Out:
# ################ T1 ################
#
# ### Unix Timestamp : 1634304690 ###
# X1  : Data size = 601
# Message published successfully. Data Size: 601
#
# ################ T2 ################
#
# ### Unix Timestamp : 1634304701 ###
# X2  : Data size = 610
# Y1  : Data size = 57
# Message published successfully. Data Size: 667
#
# ################ T3 ################
#
# ### Unix Timestamp : 1634304711 ###
# X3  : Data size = 585
# Y2  : Data size = 58
# Message published successfully. Data Size: 643
#
# ################ T4 ################
#
# ### Unix Timestamp : 1634304721 ###
# X4  : Data size = 587
# Y3  : Data size = 47
# Message published successfully. Data Size: 634
#
# ################ T5 ################
#
# ### Unix Timestamp : 1634304731 ###
# X5  : Data size = 593
# Y4  : Data size = 51
# Message published successfully. Data Size: 644
#
# ################ T6 ################
#
# ### Unix Timestamp : 1634304741 ###
# X6  : Data size = 546
# Y5  : Data size = 47
# Message published successfully. Data Size: 593
#
# ################ T7 ################
#
# ### Unix Timestamp : 1634304751 ###
# X7  : Data size = 584
# Y6  : Data size = 56
# Message published successfully. Data Size: 640
#
# ################ T8 ################
#
# ### Unix Timestamp : 1634304761 ###
# X8  : Data size = 593
# Y7  : Data size = 53
# Message published successfully. Data Size: 646
#
# ################ T9 ################
#
# ### Unix Timestamp : 1634304771 ###
# X9  : Data size = 616
# Y8  : Data size = 59
# Message published successfully. Data Size: 675
#
# ################ T10 ################
#
# ### Unix Timestamp : 1634304782 ###
# X10  : Data size = 606
# Y9  : Data size = 56
# Message published successfully. Data Size: 662
#
# ################ T11 ################
#
# ### Unix Timestamp : 1634304792 ###
# X11  : Data size = 605
# Y10  : Data size = 51
# Message published successfully. Data Size: 656
#
# ################ T12 ################
#
# ### Unix Timestamp : 1634304802 ###
# X12  : Data size = 625
# Y11  : Data size = 55
# Message published successfully. Data Size: 680
#
# ################ T13 ################
#
# ### Unix Timestamp : 1634304812 ###
# X13  : Data size = 605
# Y12  : Data size = 50
# Message published successfully. Data Size: 655
#
# ################ T14 ################
#
# ### Unix Timestamp : 1634304822 ###
# X14  : Data size = 555
# Y13  : Data size = 42
# Message published successfully. Data Size: 597
#
# ################ T15 ################
#
# ### Unix Timestamp : 1634304832 ###
# X15  : Data size = 623
# Y14  : Data size = 52
# Message published successfully. Data Size: 675
#
# ################ T16 ################
#
# ### Unix Timestamp : 1634304842 ###
# X16  : Data size = 622
# Y15  : Data size = 54
# Message published successfully. Data Size: 676
#
# ################ T17 ################
#
# ### Unix Timestamp : 1634304852 ###
# X17  : Data size = 623
# Y16  : Data size = 54
# Message published successfully. Data Size: 677
#
# ################ T18 ################
#
# ### Unix Timestamp : 1634304862 ###
# X18  : Data size = 546
# Y17  : Data size = 46
# Message published successfully. Data Size: 592
#
# ################ T19 ################
#
# ### Unix Timestamp : 1634304872 ###
# X19  : Data size = 587
# Y18  : Data size = 56
# Message published successfully. Data Size: 643
#
# ################ T20 ################
#
# ### Unix Timestamp : 1634304882 ###
# X20  : Data size = 648
# Y19  : Data size = 51
# Message published successfully. Data Size: 699
#
# ################ T21 ################
#
# ### Unix Timestamp : 1634304892 ###
# X21  : Data size = 589
# Y20  : Data size = 55
# Message published successfully. Data Size: 644
#
# ################ T22 ################
#
# ### Unix Timestamp : 1634304902 ###
# X22  : Data size = 644
# Y21  : Data size = 48
# Message published successfully. Data Size: 692
#
# ################ T23 ################
#
# ### Unix Timestamp : 1634304912 ###
# X23  : Data size = 581
# Y22  : Data size = 59
# Message published successfully. Data Size: 640
#
# ################ T24 ################
#
# ### Unix Timestamp : 1634304923 ###
# X24  : Data size = 581
# Y23  : Data size = 52
# Message published successfully. Data Size: 633
#
# ################ T25 ################
#
# ### Unix Timestamp : 1634304933 ###
# X25  : Data size = 595
# Y24  : Data size = 55
# Message published successfully. Data Size: 650
#
# ################ T26 ################
#
# ### Unix Timestamp : 1634304943 ###
# X26  : Data size = 620
# Y25  : Data size = 50
# Message published successfully. Data Size: 670
#
# ################ T27 ################
#
# ### Unix Timestamp : 1634304953 ###
# X27  : Data size = 626
# Y26  : Data size = 54
# Message published successfully. Data Size: 680
#
# ################ T28 ################
#
# ### Unix Timestamp : 1634304963 ###
# X28  : Data size = 581
# Y27  : Data size = 57
# Message published successfully. Data Size: 638
#
# ################ T29 ################
#
# ### Unix Timestamp : 1634304973 ###
# X29  : Data size = 625
# Y28  : Data size = 53
# Message published successfully. Data Size: 678
#
# ################ T30 ################
#
# ### Unix Timestamp : 1634304983 ###
# X30  : Data size = 593
# Y29  : Data size = 50
# Message published successfully. Data Size: 643
#
# ################ T31 ################
#
# ### Unix Timestamp : 1634304993 ###
# X31  : Data size = 580
# Y30  : Data size = 47
# Message published successfully. Data Size: 627
#
# ################ T32 ################
#
# ### Unix Timestamp : 1634305003 ###
# X32  : Data size = 568
# Y31  : Data size = 56
# Message published successfully. Data Size: 624
#
# ################ T33 ################
#
# ### Unix Timestamp : 1634305013 ###
# X33  : Data size = 616
# Y32  : Data size = 49
# Message published successfully. Data Size: 665
#
# ################ T34 ################
#
# ### Unix Timestamp : 1634305023 ###
# X34  : Data size = 613
# Y33  : Data size = 44
# Message published successfully. Data Size: 657
#
# ################ T35 ################
#
# ### Unix Timestamp : 1634305033 ###
# X35  : Data size = 594
# Y34  : Data size = 62
# Message published successfully. Data Size: 656
#
# ################ T36 ################
#
# ### Unix Timestamp : 1634305043 ###
# X36  : Data size = 588
# Y35  : Data size = 50
# Message published successfully. Data Size: 638
#
# ################ T37 ################
#
# ### Unix Timestamp : 1634305053 ###
# X37  : Data size = 600
# Y36  : Data size = 55
# Message published successfully. Data Size: 655
#
# ################ T38 ################
#
# ### Unix Timestamp : 1634305064 ###
# X38  : Data size = 585
# Y37  : Data size = 52
# Message published successfully. Data Size: 637
#
# ################ T39 ################
#
# ### Unix Timestamp : 1634305074 ###
# X39  : Data size = 613
# Y38  : Data size = 55
# Message published successfully. Data Size: 668
#
# ################ T40 ################
#
# ### Unix Timestamp : 1634305084 ###
# X40  : Data size = 628
# Y39  : Data size = 50
# Message published successfully. Data Size: 678
#
# ################ T41 ################
#
# ### Unix Timestamp : 1634305094 ###
# X41  : Data size = 581
# Y40  : Data size = 56
# Message published successfully. Data Size: 637
#
# ################ T42 ################
#
# ### Unix Timestamp : 1634305104 ###
# X42  : Data size = 638
# Y41  : Data size = 60
# Message published successfully. Data Size: 698
#
# ################ T43 ################
#
# ### Unix Timestamp : 1634305114 ###
# X43  : Data size = 637
# Y42  : Data size = 52
# Message published successfully. Data Size: 689
#
# ################ T44 ################
#
# ### Unix Timestamp : 1634305124 ###
# X44  : Data size = 631
# Y43  : Data size = 50
# Message published successfully. Data Size: 681
#
# ################ T45 ################
#
# ### Unix Timestamp : 1634305134 ###
# X45  : Data size = 595
# Y44  : Data size = 52
# Message published successfully. Data Size: 647
#
# ################ T46 ################
#
# ### Unix Timestamp : 1634305144 ###
# X46  : Data size = 563
# Y45  : Data size = 53
# Message published successfully. Data Size: 616
#
# ################ T47 ################
#
# ### Unix Timestamp : 1634305154 ###
# X47  : Data size = 597
# Y46  : Data size = 44
# Message published successfully. Data Size: 641
#
# ################ T48 ################
#
# ### Unix Timestamp : 1634305164 ###
# X48  : Data size = 581
# Y47  : Data size = 46
# Message published successfully. Data Size: 627
#
# ################ T49 ################
#
# ### Unix Timestamp : 1634305174 ###
# X49  : Data size = 573
# Y48  : Data size = 50
# Message published successfully. Data Size: 623
#
# ################ T50 ################
#
# ### Unix Timestamp : 1634305184 ###
# X50  : Data size = 597
# Y49  : Data size = 51
# Message published successfully. Data Size: 648
#
# ################ T51 ################
#
# ### Unix Timestamp : 1634305194 ###
# X51  : Data size = 585
# Y50  : Data size = 54
# Message published successfully. Data Size: 639
#
# ################ T52 ################
#
# ### Unix Timestamp : 1634305204 ###
# X52  : Data size = 617
# Y51  : Data size = 49
# Message published successfully. Data Size: 666
#
# ################ T53 ################
#
# ### Unix Timestamp : 1634305215 ###
# X53  : Data size = 603
# Y52  : Data size = 52
# Message published successfully. Data Size: 655
#
# ################ T54 ################
#
# ### Unix Timestamp : 1634305225 ###
# X54  : Data size = 570
# Y53  : Data size = 51
# Message published successfully. Data Size: 621
#
# ################ T55 ################
#
# ### Unix Timestamp : 1634305235 ###
# X55  : Data size = 627
# Y54  : Data size = 46
# Message published successfully. Data Size: 673
#
# ################ T56 ################
#
# ### Unix Timestamp : 1634305245 ###
# X56  : Data size = 584
# Y55  : Data size = 54
# Message published successfully. Data Size: 638
#
# ################ T57 ################
#
# ### Unix Timestamp : 1634305255 ###
# X57  : Data size = 607
# Y56  : Data size = 52
# Message published successfully. Data Size: 659
#
# ################ T58 ################
#
# ### Unix Timestamp : 1634305265 ###
# X58  : Data size = 603
# Y57  : Data size = 52
# Message published successfully. Data Size: 655
#
# ################ T59 ################
#
# ### Unix Timestamp : 1634305275 ###
# X59  : Data size = 618
# Y58  : Data size = 54
# Message published successfully. Data Size: 672
#
# ################ T60 ################
#
# ### Unix Timestamp : 1634305285 ###
# X60  : Data size = 628
# Y59  : Data size = 59
# Message published successfully. Data Size: 687
#
# ################ T61 ################
#
# ### Unix Timestamp : 1634305295 ###
# X61  : Data size = 562
# Y60  : Data size = 54
# Message published successfully. Data Size: 616
#
# ################ T62 ################
#
# ### Unix Timestamp : 1634305305 ###
# X62  : Data size = 619
# Y61  : Data size = 54
# Message published successfully. Data Size: 673
#
# ################ T63 ################
#
# ### Unix Timestamp : 1634305315 ###
# X63  : Data size = 628
# Y62  : Data size = 59
# Message published successfully. Data Size: 687
#
# ################ T64 ################
#
# ### Unix Timestamp : 1634305325 ###
# X64  : Data size = 647
# Y63  : Data size = 53
# Message published successfully. Data Size: 700
#
# ################ T65 ################
#
# ### Unix Timestamp : 1634305335 ###
# X65  : Data size = 586
# Y64  : Data size = 54
# Message published successfully. Data Size: 640
#
# ################ T66 ################
#
# ### Unix Timestamp : 1634305346 ###
# X66  : Data size = 572
# Y65  : Data size = 50
# Message published successfully. Data Size: 622
#
# ################ T67 ################
#
# ### Unix Timestamp : 1634305356 ###
# X67  : Data size = 608
# Y66  : Data size = 52
# Message published successfully. Data Size: 660
#
# ################ T68 ################
#
# ### Unix Timestamp : 1634305366 ###
# X68  : Data size = 593
# Y67  : Data size = 55
# Message published successfully. Data Size: 648
#
# ################ T69 ################
#
# ### Unix Timestamp : 1634305376 ###
# X69  : Data size = 643
# Y68  : Data size = 54
# Message published successfully. Data Size: 697
#
# ################ T70 ################
#
# ### Unix Timestamp : 1634305386 ###
# X70  : Data size = 564
# Y69  : Data size = 56
# Message published successfully. Data Size: 620
#
# ################ T71 ################
#
# ### Unix Timestamp : 1634305396 ###
# X71  : Data size = 574
# Y70  : Data size = 46
# Message published successfully. Data Size: 620
#
# ################ T72 ################
#
# ### Unix Timestamp : 1634305406 ###
# X72  : Data size = 582
# Y71  : Data size = 55
# Message published successfully. Data Size: 637
#
# ################ T73 ################
#
# ### Unix Timestamp : 1634305416 ###
# X73  : Data size = 594
# Y72  : Data size = 61
# Message published successfully. Data Size: 655
#
# ################ T74 ################
#
# ### Unix Timestamp : 1634305426 ###
# X74  : Data size = 592
# Y73  : Data size = 59
# Message published successfully. Data Size: 651
#
# ################ T75 ################
#
# ### Unix Timestamp : 1634305436 ###
# X75  : Data size = 585
# Y74  : Data size = 53
# Message published successfully. Data Size: 638
#
# ################ T76 ################
#
# ### Unix Timestamp : 1634305446 ###
# X76  : Data size = 602
# Y75  : Data size = 46
# Message published successfully. Data Size: 648
#
# ################ T77 ################
#
# ### Unix Timestamp : 1634305456 ###
# X77  : Data size = 607
# Y76  : Data size = 52
# Message published successfully. Data Size: 659
#
# ################ T78 ################
#
# ### Unix Timestamp : 1634305466 ###
# X78  : Data size = 616
# Y77  : Data size = 51
# Message published successfully. Data Size: 667
#
# ################ T79 ################
#
# ### Unix Timestamp : 1634305476 ###
# X79  : Data size = 607
# Y78  : Data size = 48
# Message published successfully. Data Size: 655
#
# ################ T80 ################
#
# ### Unix Timestamp : 1634305487 ###
# X80  : Data size = 567
# Y79  : Data size = 53
# Message published successfully. Data Size: 620
#
# ################ T81 ################
#
# ### Unix Timestamp : 1634305497 ###
# X81  : Data size = 624
# Y80  : Data size = 53
# Message published successfully. Data Size: 677
#
# ################ T82 ################
#
# ### Unix Timestamp : 1634305507 ###
# X82  : Data size = 645
# Y81  : Data size = 54
# Message published successfully. Data Size: 699
#
# ################ T83 ################
#
# ### Unix Timestamp : 1634305517 ###
# X83  : Data size = 615
# Y82  : Data size = 44
# Message published successfully. Data Size: 659
#
# ################ T84 ################
#
# ### Unix Timestamp : 1634305527 ###
# X84  : Data size = 605
# Y83  : Data size = 50
# Message published successfully. Data Size: 655
#
# ################ T85 ################
#
# ### Unix Timestamp : 1634305537 ###
# X85  : Data size = 566
# Y84  : Data size = 50
# Message published successfully. Data Size: 616
#
# ################ T86 ################
#
# ### Unix Timestamp : 1634305547 ###
# X86  : Data size = 603
# Y85  : Data size = 51
# Message published successfully. Data Size: 654
#
# ################ T87 ################
#
# ### Unix Timestamp : 1634305557 ###
# X87  : Data size = 620
# Y86  : Data size = 50
# Message published successfully. Data Size: 670
#
# ################ T88 ################
#
# ### Unix Timestamp : 1634305567 ###
# X88  : Data size = 537
# Y87  : Data size = 48
# Message published successfully. Data Size: 585
#
# ################ T89 ################
#
# ### Unix Timestamp : 1634305577 ###
# X89  : Data size = 580
# Y88  : Data size = 53
# Message published successfully. Data Size: 633
#
# ################ T90 ################
#
# ### Unix Timestamp : 1634305587 ###
# X90  : Data size = 577
# Y89  : Data size = 56
# Message published successfully. Data Size: 633
#
# ################ T91 ################
#
# ### Unix Timestamp : 1634305597 ###
# X91  : Data size = 542
# Y90  : Data size = 55
# Message published successfully. Data Size: 597
#
# ################ T92 ################
#
# ### Unix Timestamp : 1634305607 ###
# X92  : Data size = 614
# Y91  : Data size = 55
# Message published successfully. Data Size: 669
#
# ################ T93 ################
#
# ### Unix Timestamp : 1634305617 ###
# X93  : Data size = 611
# Y92  : Data size = 54
# Message published successfully. Data Size: 665
#
# ################ T94 ################
#
# ### Unix Timestamp : 1634305627 ###
# X94  : Data size = 616
# Y93  : Data size = 52
# Message published successfully. Data Size: 668
#
# ################ T95 ################
#
# ### Unix Timestamp : 1634305638 ###
# X95  : Data size = 589
# Y94  : Data size = 51
# Message published successfully. Data Size: 640
#
# ################ T96 ################
#
# ### Unix Timestamp : 1634305648 ###
# X96  : Data size = 563
# Y95  : Data size = 53
# Message published successfully. Data Size: 616
#
# ################ T97 ################
#
# ### Unix Timestamp : 1634305658 ###
# X97  : Data size = 626
# Y96  : Data size = 50
# Message published successfully. Data Size: 676
#
# ################ T98 ################
#
# ### Unix Timestamp : 1634305668 ###
# X98  : Data size = 613
# Y97  : Data size = 54
# Message published successfully. Data Size: 667
#
# ################ T99 ################
#
# ### Unix Timestamp : 1634305678 ###
# X99  : Data size = 603
# Y98  : Data size = 60
# Message published successfully. Data Size: 663
#
# ################ T100 ################
#
# ### Unix Timestamp : 1634305688 ###
# X100  : Data size = 632
# Y99  : Data size = 50
# Message published successfully. Data Size: 682
#
# ################ T101 ################
#
# ### Unix Timestamp : 1634305698 ###
# X101  : Data size = 598
# Y100  : Data size = 56
# Message published successfully. Data Size: 654
#
# ################ T102 ################
#
# ### Unix Timestamp : 1634305708 ###
# X102  : Data size = 579
# Y101  : Data size = 57
# Message published successfully. Data Size: 636
#
# ################ T103 ################
#
# ### Unix Timestamp : 1634305718 ###
# X103  : Data size = 555
# Y102  : Data size = 51
# Message published successfully. Data Size: 606
#
# ################ T104 ################
#
# ### Unix Timestamp : 1634305728 ###
# X104  : Data size = 626
# Y103  : Data size = 49
# Message published successfully. Data Size: 675
#
# ################ T105 ################
#
# ### Unix Timestamp : 1634305738 ###
# X105  : Data size = 573
# Y104  : Data size = 46
# Message published successfully. Data Size: 619
#
# ################ T106 ################
#
# ### Unix Timestamp : 1634305748 ###
# X106  : Data size = 603
# Y105  : Data size = 56
# Message published successfully. Data Size: 659
#
# ################ T107 ################
#
# ### Unix Timestamp : 1634305758 ###
# X107  : Data size = 597
# Y106  : Data size = 53
# Message published successfully. Data Size: 650
#
# ################ T108 ################
#
# ### Unix Timestamp : 1634305768 ###
# X108  : Data size = 605
# Y107  : Data size = 57
# Message published successfully. Data Size: 662
#
# ################ T109 ################
#
# ### Unix Timestamp : 1634305779 ###
# X109  : Data size = 586
# Y108  : Data size = 47
# Message published successfully. Data Size: 633
#
# ################ T110 ################
#
# ### Unix Timestamp : 1634305789 ###
# X110  : Data size = 578
# Y109  : Data size = 53
# Message published successfully. Data Size: 631
#
# ################ T111 ################
#
# ### Unix Timestamp : 1634305799 ###
# X111  : Data size = 547
# Y110  : Data size = 50
# Message published successfully. Data Size: 597
#
# ################ T112 ################
#
# ### Unix Timestamp : 1634305809 ###
# X112  : Data size = 609
# Y111  : Data size = 57
# Message published successfully. Data Size: 666
#
# ################ T113 ################
#
# ### Unix Timestamp : 1634305819 ###
# X113  : Data size = 619
# Y112  : Data size = 48
# Message published successfully. Data Size: 667
#
# ################ T114 ################
#
# ### Unix Timestamp : 1634305829 ###
# X114  : Data size = 599
# Y113  : Data size = 49
# Message published successfully. Data Size: 648
#
# ################ T115 ################
#
# ### Unix Timestamp : 1634305839 ###
# X115  : Data size = 600
# Y114  : Data size = 59
# Message published successfully. Data Size: 659
#
# ################ T116 ################
#
# ### Unix Timestamp : 1634305849 ###
# X116  : Data size = 623
# Y115  : Data size = 55
# Message published successfully. Data Size: 678
#
# ################ T117 ################
#
# ### Unix Timestamp : 1634305859 ###
# X117  : Data size = 540
# Y116  : Data size = 50
# Message published successfully. Data Size: 590
#
# ################ T118 ################
#
# ### Unix Timestamp : 1634305869 ###
# X118  : Data size = 571
# Y117  : Data size = 51
# Message published successfully. Data Size: 622
#
# ################ T119 ################
#
# ### Unix Timestamp : 1634305879 ###
# X119  : Data size = 577
# Y118  : Data size = 55
# Message published successfully. Data Size: 632
#
# ################ T120 ################
#
# ### Unix Timestamp : 1634305889 ###
# X120  : Data size = 572
# Y119  : Data size = 55
# Message published successfully. Data Size: 627
#
# ################ T121 ################
#
# ### Unix Timestamp : 1634305899 ###
# X121  : Data size = 567
# Y120  : Data size = 51
# Message published successfully. Data Size: 618
#
# ################ T122 ################
#
# ### Unix Timestamp : 1634305909 ###
# X122  : Data size = 555
# Y121  : Data size = 46
# Message published successfully. Data Size: 601
#
# ################ T123 ################
#
# ### Unix Timestamp : 1634305920 ###
# X123  : Data size = 649
# Y122  : Data size = 62
# Message published successfully. Data Size: 711
#
# ################ T124 ################
#
# ### Unix Timestamp : 1634305930 ###
# X124  : Data size = 595
# Y123  : Data size = 46
# Message published successfully. Data Size: 641
#
# ################ T125 ################
#
# ### Unix Timestamp : 1634305940 ###
# X125  : Data size = 600
# Y124  : Data size = 44
# Message published successfully. Data Size: 644
#
# ################ T126 ################
#
# ### Unix Timestamp : 1634305950 ###
# X126  : Data size = 532
# Y125  : Data size = 55
# Message published successfully. Data Size: 587
#
# ################ T127 ################
#
# ### Unix Timestamp : 1634305960 ###
# X127  : Data size = 580
# Y126  : Data size = 55
# Message published successfully. Data Size: 635
#
# ################ T128 ################
#
# ### Unix Timestamp : 1634305970 ###
# X128  : Data size = 575
# Y127  : Data size = 52
# Message published successfully. Data Size: 627
#
# ################ T129 ################
#
# ### Unix Timestamp : 1634305980 ###
# X129  : Data size = 614
# Y128  : Data size = 49
# Message published successfully. Data Size: 663
#
# ################ T130 ################
#
# ### Unix Timestamp : 1634305990 ###
# X130  : Data size = 595
# Y129  : Data size = 59
# Message published successfully. Data Size: 654
#
# ################ T131 ################
#
# ### Unix Timestamp : 1634306000 ###
# X131  : Data size = 608
# Y130  : Data size = 52
# Message published successfully. Data Size: 660
#
# ################ T132 ################
#
# ### Unix Timestamp : 1634306010 ###
# X132  : Data size = 584
# Y131  : Data size = 58
# Message published successfully. Data Size: 642
#
# ################ T133 ################
#
# ### Unix Timestamp : 1634306020 ###
# X133  : Data size = 634
# Y132  : Data size = 53
# Message published successfully. Data Size: 687
#
# ################ T134 ################
#
# ### Unix Timestamp : 1634306030 ###
# X134  : Data size = 632
# Y133  : Data size = 58
# Message published successfully. Data Size: 690
#
# ################ T135 ################
#
# ### Unix Timestamp : 1634306040 ###
# X135  : Data size = 591
# Y134  : Data size = 49
# Message published successfully. Data Size: 640
#
# ################ T136 ################
#
# ### Unix Timestamp : 1634306051 ###
# X136  : Data size = 619
# Y135  : Data size = 51
# Message published successfully. Data Size: 670
#
# ################ T137 ################
#
# ### Unix Timestamp : 1634306061 ###
# X137  : Data size = 570
# Y136  : Data size = 57
# Message published successfully. Data Size: 627
#
# ################ T138 ################
#
# ### Unix Timestamp : 1634306071 ###
# X138  : Data size = 624
# Y137  : Data size = 53
# Message published successfully. Data Size: 677
#
# ################ T139 ################
#
# ### Unix Timestamp : 1634306081 ###
# X139  : Data size = 604
# Y138  : Data size = 58
# Message published successfully. Data Size: 662
#
# ################ T140 ################
#
# ### Unix Timestamp : 1634306091 ###
# X140  : Data size = 621
# Y139  : Data size = 48
# Message published successfully. Data Size: 669
#
# ################ T141 ################
#
# ### Unix Timestamp : 1634306101 ###
# X141  : Data size = 569
# Y140  : Data size = 53
# Message published successfully. Data Size: 622
#
# ################ T142 ################
#
# ### Unix Timestamp : 1634306111 ###
# X142  : Data size = 582
# Y141  : Data size = 48
# Message published successfully. Data Size: 630
#
# ################ T143 ################
#
# ### Unix Timestamp : 1634306121 ###
# X143  : Data size = 625
# Y142  : Data size = 58
# Message published successfully. Data Size: 683
#
# ################ T144 ################
#
# ### Unix Timestamp : 1634306131 ###
# X144  : Data size = 626
# Y143  : Data size = 56
# Message published successfully. Data Size: 682
#
# ################ T145 ################
#
# ### Unix Timestamp : 1634306141 ###
# X145  : Data size = 645
# Y144  : Data size = 49
# Message published successfully. Data Size: 694
#
# ################ T146 ################
#
# ### Unix Timestamp : 1634306151 ###
# X146  : Data size = 573
# Y145  : Data size = 52
# Message published successfully. Data Size: 625
#
# ################ T147 ################
#
# ### Unix Timestamp : 1634306161 ###
# X147  : Data size = 591
# Y146  : Data size = 46
# Message published successfully. Data Size: 637
#
# ################ T148 ################
#
# ### Unix Timestamp : 1634306171 ###
# X148  : Data size = 610
# Y147  : Data size = 48
# Message published successfully. Data Size: 658
#
# ################ T149 ################
#
# ### Unix Timestamp : 1634306181 ###
# X149  : Data size = 602
# Y148  : Data size = 50
# Message published successfully. Data Size: 652
#
# ################ T150 ################
#
# ### Unix Timestamp : 1634306192 ###
# X150  : Data size = 609
# Y149  : Data size = 50
# Message published successfully. Data Size: 659
#
# ################ T151 ################
#
# ### Unix Timestamp : 1634306202 ###
# X151  : Data size = 581
# Y150  : Data size = 55
# Message published successfully. Data Size: 636
#
# ################ T152 ################
#
# ### Unix Timestamp : 1634306212 ###
# X152  : Data size = 609
# Y151  : Data size = 54
# Message published successfully. Data Size: 663
#
# ################ T153 ################
#
# ### Unix Timestamp : 1634306222 ###
# X153  : Data size = 582
# Y152  : Data size = 50
# Message published successfully. Data Size: 632
#
# ################ T154 ################
#
# ### Unix Timestamp : 1634306232 ###
# X154  : Data size = 600
# Y153  : Data size = 52
# Message published successfully. Data Size: 652
#
# ################ T155 ################
#
# ### Unix Timestamp : 1634306242 ###
# X155  : Data size = 589
# Y154  : Data size = 48
# Message published successfully. Data Size: 637
#
# ################ T156 ################
#
# ### Unix Timestamp : 1634306252 ###
# X156  : Data size = 610
# Y155  : Data size = 47
# Message published successfully. Data Size: 657
#
# ################ T157 ################
#
# ### Unix Timestamp : 1634306262 ###
# X157  : Data size = 609
# Y156  : Data size = 53
# Message published successfully. Data Size: 662
#
# ################ T158 ################
#
# ### Unix Timestamp : 1634306272 ###
# X158  : Data size = 654
# Y157  : Data size = 56
# Message published successfully. Data Size: 710
#
# ################ T159 ################
#
# ### Unix Timestamp : 1634306282 ###
# X159  : Data size = 522
# Y158  : Data size = 53
# Message published successfully. Data Size: 575
#
# ################ T160 ################
#
# ### Unix Timestamp : 1634306292 ###
# X160  : Data size = 601
# Y159  : Data size = 59
# Message published successfully. Data Size: 660
#
# ################ T161 ################
#
# ### Unix Timestamp : 1634306302 ###
# X161  : Data size = 640
# Y160  : Data size = 54
# Message published successfully. Data Size: 694
#
# ################ T162 ################
#
# ### Unix Timestamp : 1634306312 ###
# X162  : Data size = 598
# Y161  : Data size = 52
# Message published successfully. Data Size: 650
#
# ################ T163 ################
#
# ### Unix Timestamp : 1634306322 ###
# X163  : Data size = 580
# Y162  : Data size = 62
# Message published successfully. Data Size: 642
#
# ################ T164 ################
#
# ### Unix Timestamp : 1634306332 ###
# X164  : Data size = 601
# Y163  : Data size = 60
# Message published successfully. Data Size: 661
#
# ################ T165 ################
#
# ### Unix Timestamp : 1634306343 ###
# X165  : Data size = 584
# Y164  : Data size = 51
# Message published successfully. Data Size: 635
#
# ################ T166 ################
#
# ### Unix Timestamp : 1634306353 ###
# X166  : Data size = 585
# Y165  : Data size = 51
# Message published successfully. Data Size: 636
#
# ################ T167 ################
#
# ### Unix Timestamp : 1634306363 ###
# X167  : Data size = 562
# Y166  : Data size = 54
# Message published successfully. Data Size: 616
#
# ################ T168 ################
#
# ### Unix Timestamp : 1634306373 ###
# X168  : Data size = 567
# Y167  : Data size = 49
# Message published successfully. Data Size: 616
#
# ################ T169 ################
#
# ### Unix Timestamp : 1634306383 ###
# X169  : Data size = 596
# Y168  : Data size = 58
# Message published successfully. Data Size: 654
#
# ################ T170 ################
#
# ### Unix Timestamp : 1634306393 ###
# X170  : Data size = 616
# Y169  : Data size = 49
# Message published successfully. Data Size: 665
#
# ################ T171 ################
#
# ### Unix Timestamp : 1634306403 ###
# X171  : Data size = 571
# Y170  : Data size = 51
# Message published successfully. Data Size: 622
#
# ################ T172 ################
#
# ### Unix Timestamp : 1634306413 ###
# X172  : Data size = 606
# Y171  : Data size = 49
# Message published successfully. Data Size: 655
#
# ################ T173 ################
#
# ### Unix Timestamp : 1634306423 ###
# X173  : Data size = 568
# Y172  : Data size = 50
# Message published successfully. Data Size: 618
#
# ################ T174 ################
#
# ### Unix Timestamp : 1634306433 ###
# X174  : Data size = 641
# Y173  : Data size = 49
# Message published successfully. Data Size: 690
#
# ################ T175 ################
#
# ### Unix Timestamp : 1634306443 ###
# X175  : Data size = 596
# Y174  : Data size = 56
# Message published successfully. Data Size: 652
#
# ################ T176 ################
#
# ### Unix Timestamp : 1634306453 ###
# X176  : Data size = 592
# Y175  : Data size = 56
# Message published successfully. Data Size: 648
#
# ################ T177 ################
#
# ### Unix Timestamp : 1634306463 ###
# X177  : Data size = 560
# Y176  : Data size = 51
# Message published successfully. Data Size: 611
#
# ################ T178 ################
#
# ### Unix Timestamp : 1634306473 ###
# X178  : Data size = 593
# Y177  : Data size = 49
# Message published successfully. Data Size: 642
#
# ################ T179 ################
#
# ### Unix Timestamp : 1634306483 ###
# X179  : Data size = 601
# Y178  : Data size = 52
# Message published successfully. Data Size: 653
#
# ################ T180 ################
#
# ### Unix Timestamp : 1634306494 ###
# X180  : Data size = 559
# Y179  : Data size = 62
# Message published successfully. Data Size: 621
#
# ################ T181 ################
#
# ### Unix Timestamp : 1634306504 ###
# X181  : Data size = 611
# Y180  : Data size = 50
# Message published successfully. Data Size: 661
#
# ################ T182 ################
#
# ### Unix Timestamp : 1634306514 ###
# X182  : Data size = 580
# Y181  : Data size = 51
# Message published successfully. Data Size: 631
#
# ################ T183 ################
#
# ### Unix Timestamp : 1634306524 ###
# X183  : Data size = 579
# Y182  : Data size = 50
# Message published successfully. Data Size: 629
#
# ################ T184 ################
#
# ### Unix Timestamp : 1634306534 ###
# X184  : Data size = 570
# Y183  : Data size = 45
# Message published successfully. Data Size: 615
#
# ################ T185 ################
#
# ### Unix Timestamp : 1634306544 ###
# X185  : Data size = 599
# Y184  : Data size = 48
# Message published successfully. Data Size: 647
#
# ################ T186 ################
#
# ### Unix Timestamp : 1634306554 ###
# X186  : Data size = 586
# Y185  : Data size = 49
# Message published successfully. Data Size: 635
#
# ################ T187 ################
#
# ### Unix Timestamp : 1634306564 ###
# X187  : Data size = 613
# Y186  : Data size = 58
# Message published successfully. Data Size: 671
#
# ################ T188 ################
#
# ### Unix Timestamp : 1634306574 ###
# X188  : Data size = 573
# Y187  : Data size = 48
# Message published successfully. Data Size: 621
#
# ################ T189 ################
#
# ### Unix Timestamp : 1634306584 ###
# X189  : Data size = 562
# Y188  : Data size = 52
# Message published successfully. Data Size: 614
#
# ################ T190 ################
#
# ### Unix Timestamp : 1634306594 ###
# X190  : Data size = 575
# Y189  : Data size = 51
# Message published successfully. Data Size: 626
#
# ################ T191 ################
#
# ### Unix Timestamp : 1634306604 ###
# X191  : Data size = 588
# Y190  : Data size = 57
# Message published successfully. Data Size: 645
#
# ################ T192 ################
#
# ### Unix Timestamp : 1634306614 ###
# X192  : Data size = 595
# Y191  : Data size = 55
# Message published successfully. Data Size: 650
#
# ################ T193 ################
#
# ### Unix Timestamp : 1634306624 ###
# X193  : Data size = 545
# Y192  : Data size = 61
# Message published successfully. Data Size: 606
#
# ################ T194 ################
#
# ### Unix Timestamp : 1634306634 ###
# X194  : Data size = 611
# Y193  : Data size = 47
# Message published successfully. Data Size: 658
#
# ################ T195 ################
#
# ### Unix Timestamp : 1634306645 ###
# X195  : Data size = 609
# Y194  : Data size = 54
# Message published successfully. Data Size: 663
#
# ################ T196 ################
#
# ### Unix Timestamp : 1634306655 ###
# X196  : Data size = 600
# Y195  : Data size = 57
# Message published successfully. Data Size: 657
#
# ################ T197 ################
#
# ### Unix Timestamp : 1634306665 ###
# X197  : Data size = 582
# Y196  : Data size = 55
# Message published successfully. Data Size: 637
#
# ################ T198 ################
#
# ### Unix Timestamp : 1634306675 ###
# X198  : Data size = 565
# Y197  : Data size = 50
# Message published successfully. Data Size: 615
#
# ################ T199 ################
#
# ### Unix Timestamp : 1634306685 ###
# X199  : Data size = 598
# Y198  : Data size = 52
# Message published successfully. Data Size: 650
#
# ################ T200 ################
#
# ### Unix Timestamp : 1634306695 ###
# X200  : Data size = 631
# Y199  : Data size = 39
# Message published successfully. Data Size: 670
#
# ################ T201 ################
#
# ### Unix Timestamp : 1634306705 ###
# X201  : Data size = 571
# Y200  : Data size = 48
# Message published successfully. Data Size: 619
#
# ################ T202 ################
#
# ### Unix Timestamp : 1634306715 ###
# X202  : Data size = 578
# Y201  : Data size = 60
# Message published successfully. Data Size: 638
#
# ################ T203 ################
#
# ### Unix Timestamp : 1634306725 ###
# X203  : Data size = 632
# Y202  : Data size = 54
# Message published successfully. Data Size: 686
#
# ################ T204 ################
#
# ### Unix Timestamp : 1634306735 ###
# X204  : Data size = 565
# Y203  : Data size = 58
# Message published successfully. Data Size: 623
#
# ################ T205 ################
#
# ### Unix Timestamp : 1634306745 ###
# X205  : Data size = 551
# Y204  : Data size = 45
# Message published successfully. Data Size: 596
#
# ################ T206 ################
#
# ### Unix Timestamp : 1634306755 ###
# X206  : Data size = 559
# Y205  : Data size = 52
# Message published successfully. Data Size: 611
#
# ################ T207 ################
#
# ### Unix Timestamp : 1634306765 ###
# X207  : Data size = 591
# Y206  : Data size = 48
# Message published successfully. Data Size: 639
#
# ################ T208 ################
#
# ### Unix Timestamp : 1634306775 ###
# X208  : Data size = 540
# Y207  : Data size = 58
# Message published successfully. Data Size: 598
#
# ################ T209 ################
#
# ### Unix Timestamp : 1634306786 ###
# X209  : Data size = 605
# Y208  : Data size = 49
# Message published successfully. Data Size: 654
#
# ################ T210 ################
#
# ### Unix Timestamp : 1634306796 ###
# X210  : Data size = 615
# Y209  : Data size = 58
# Message published successfully. Data Size: 673
#
# ################ T211 ################
#
# ### Unix Timestamp : 1634306806 ###
# X211  : Data size = 629
# Y210  : Data size = 49
# Message published successfully. Data Size: 678
#
# ################ T212 ################
#
# ### Unix Timestamp : 1634306816 ###
# X212  : Data size = 606
# Y211  : Data size = 48
# Message published successfully. Data Size: 654
#
# ################ T213 ################
#
# ### Unix Timestamp : 1634306826 ###
# X213  : Data size = 577
# Y212  : Data size = 61
# Message published successfully. Data Size: 638
#
# ################ T214 ################
#
# ### Unix Timestamp : 1634306836 ###
# X214  : Data size = 613
# Y213  : Data size = 52
# Message published successfully. Data Size: 665
#
# ################ T215 ################
#
# ### Unix Timestamp : 1634306846 ###
# X215  : Data size = 606
# Y214  : Data size = 53
# Message published successfully. Data Size: 659
#
# ################ T216 ################
#
# ### Unix Timestamp : 1634306856 ###
# X216  : Data size = 637
# Y215  : Data size = 46
# Message published successfully. Data Size: 683
#
# ################ T217 ################
#
# ### Unix Timestamp : 1634306866 ###
# X217  : Data size = 613
# Y216  : Data size = 51
# Message published successfully. Data Size: 664
#
# ################ T218 ################
#
# ### Unix Timestamp : 1634306876 ###
# X218  : Data size = 645
# Y217  : Data size = 60
# Message published successfully. Data Size: 705
#
# ################ T219 ################
#
# ### Unix Timestamp : 1634306886 ###
# X219  : Data size = 594
# Y218  : Data size = 61
# Message published successfully. Data Size: 655
#
# ################ T220 ################
#
# ### Unix Timestamp : 1634306896 ###
# X220  : Data size = 586
# Y219  : Data size = 48
# Message published successfully. Data Size: 634
#
# ################ T221 ################
#
# ### Unix Timestamp : 1634306906 ###
# X221  : Data size = 611
# Y220  : Data size = 51
# Message published successfully. Data Size: 662
#
# ################ T222 ################
#
# ### Unix Timestamp : 1634306916 ###
# X222  : Data size = 630
# Y221  : Data size = 51
# Message published successfully. Data Size: 681
#
# ################ T223 ################
#
# ### Unix Timestamp : 1634306926 ###
# X223  : Data size = 613
# Y222  : Data size = 56
# Message published successfully. Data Size: 669
#
# ################ T224 ################
#
# ### Unix Timestamp : 1634306936 ###
# X224  : Data size = 567
# Y223  : Data size = 49
# Message published successfully. Data Size: 616
#
# ################ T225 ################
#
# ### Unix Timestamp : 1634306947 ###
# X225  : Data size = 565
# Y224  : Data size = 51
# Message published successfully. Data Size: 616
#
# ################ T226 ################
#
# ### Unix Timestamp : 1634306957 ###
# X226  : Data size = 554
# Y225  : Data size = 48
# Message published successfully. Data Size: 602
#
# ################ T227 ################
#
# ### Unix Timestamp : 1634306967 ###
# X227  : Data size = 590
# Y226  : Data size = 55
# Message published successfully. Data Size: 645
#
# ################ T228 ################
#
# ### Unix Timestamp : 1634306977 ###
# X228  : Data size = 615
# Y227  : Data size = 50
# Message published successfully. Data Size: 665
#
# ################ T229 ################
#
# ### Unix Timestamp : 1634306987 ###
# X229  : Data size = 603
# Y228  : Data size = 49
# Message published successfully. Data Size: 652
#
# ################ T230 ################
#
# ### Unix Timestamp : 1634306997 ###
# X230  : Data size = 612
# Y229  : Data size = 54
# Message published successfully. Data Size: 666
#
# ################ T231 ################
#
# ### Unix Timestamp : 1634307007 ###
# X231  : Data size = 593
# Y230  : Data size = 52
# Message published successfully. Data Size: 645
#
# ################ T232 ################
#
# ### Unix Timestamp : 1634307017 ###
# X232  : Data size = 605
# Y231  : Data size = 55
# Message published successfully. Data Size: 660
#
# ################ T233 ################
#
# ### Unix Timestamp : 1634307027 ###
# X233  : Data size = 572
# Y232  : Data size = 52
# Message published successfully. Data Size: 624
#
# ################ T234 ################
#
# ### Unix Timestamp : 1634307037 ###
# X234  : Data size = 581
# Y233  : Data size = 51
# Message published successfully. Data Size: 632
#
# ################ T235 ################
#
# ### Unix Timestamp : 1634307047 ###
# X235  : Data size = 593
# Y234  : Data size = 49
# Message published successfully. Data Size: 642
#
# ################ T236 ################
#
# ### Unix Timestamp : 1634307057 ###
# X236  : Data size = 584
# Y235  : Data size = 50
# Message published successfully. Data Size: 634
#
# ################ T237 ################
#
# ### Unix Timestamp : 1634307067 ###
# X237  : Data size = 567
# Y236  : Data size = 53
# Message published successfully. Data Size: 620
#
# ################ T238 ################
#
# ### Unix Timestamp : 1634307077 ###
# X238  : Data size = 644
# Y237  : Data size = 54
# Message published successfully. Data Size: 698
#
# ################ T239 ################
#
# ### Unix Timestamp : 1634307087 ###
# X239  : Data size = 611
# Y238  : Data size = 54
# Message published successfully. Data Size: 665
#
# ################ T240 ################
#
# ### Unix Timestamp : 1634307097 ###
# X240  : Data size = 622
# Y239  : Data size = 50
# Message published successfully. Data Size: 672
#
# ################ T241 ################
#
# ### Unix Timestamp : 1634307107 ###
# X241  : Data size = 618
# Y240  : Data size = 48
# Message published successfully. Data Size: 666
#
# ################ T242 ################
#
# ### Unix Timestamp : 1634307118 ###
# X242  : Data size = 608
# Y241  : Data size = 53
# Message published successfully. Data Size: 661
#
# ################ T243 ################
#
# ### Unix Timestamp : 1634307128 ###
# X243  : Data size = 574
# Y242  : Data size = 61
# Message published successfully. Data Size: 635
#
# ################ T244 ################
#
# ### Unix Timestamp : 1634307138 ###
# X244  : Data size = 581
# Y243  : Data size = 51
# Message published successfully. Data Size: 632
#
# ################ T245 ################
#
# ### Unix Timestamp : 1634307148 ###
# X245  : Data size = 604
# Y244  : Data size = 58
# Message published successfully. Data Size: 662
#
# ################ T246 ################
#
# ### Unix Timestamp : 1634307158 ###
# X246  : Data size = 599
# Y245  : Data size = 49
# Message published successfully. Data Size: 648
#
# ################ T247 ################
#
# ### Unix Timestamp : 1634307168 ###
# X247  : Data size = 624
# Y246  : Data size = 62
# Message published successfully. Data Size: 686
#
# ################ T248 ################
#
# ### Unix Timestamp : 1634307178 ###
# X248  : Data size = 648
# Y247  : Data size = 55
# Message published successfully. Data Size: 703
#
# ################ T249 ################
#
# ### Unix Timestamp : 1634307188 ###
# X249  : Data size = 556
# Y248  : Data size = 56
# Message published successfully. Data Size: 612
#
# ################ T250 ################
#
# ### Unix Timestamp : 1634307198 ###
# X250  : Data size = 581
# Y249  : Data size = 51
# Message published successfully. Data Size: 632
#
# ################ T251 ################
#
# ### Unix Timestamp : 1634307208 ###
# X251  : Data size = 608
# Y250  : Data size = 53
# Message published successfully. Data Size: 661
#
# ################ T252 ################
#
# ### Unix Timestamp : 1634307218 ###
# X252  : Data size = 580
# Y251  : Data size = 47
# Message published successfully. Data Size: 627
#
# ################ T253 ################
#
# ### Unix Timestamp : 1634307228 ###
# X253  : Data size = 631
# Y252  : Data size = 46
# Message published successfully. Data Size: 677
#
# ################ T254 ################
#
# ### Unix Timestamp : 1634307238 ###
# X254  : Data size = 617
# Y253  : Data size = 51
# Message published successfully. Data Size: 668
#
# ################ T255 ################
#
# ### Unix Timestamp : 1634307248 ###
# X255  : Data size = 599
# Y254  : Data size = 50
# Message published successfully. Data Size: 649
#
# ################ T256 ################
#
# ### Unix Timestamp : 1634307258 ###
# X256  : Data size = 541
# Y255  : Data size = 57
# Message published successfully. Data Size: 598
#
# ################ T257 ################
#
# ### Unix Timestamp : 1634307268 ###
# X257  : Data size = 561
# Y256  : Data size = 56
# Message published successfully. Data Size: 617
#
# ################ T258 ################
#
# ### Unix Timestamp : 1634307278 ###
# X258  : Data size = 599
# Y257  : Data size = 49
# Message published successfully. Data Size: 648
#
# ################ T259 ################
#
# ### Unix Timestamp : 1634307289 ###
# X259  : Data size = 577
# Y258  : Data size = 56
# Message published successfully. Data Size: 633
#
# ################ T260 ################
#
# ### Unix Timestamp : 1634307299 ###
# X260  : Data size = 620
# Y259  : Data size = 54
# Message published successfully. Data Size: 674
#
# ################ T261 ################
#
# ### Unix Timestamp : 1634307309 ###
# X261  : Data size = 577
# Y260  : Data size = 52
# Message published successfully. Data Size: 629
#
# ################ T262 ################
#
# ### Unix Timestamp : 1634307319 ###
# X262  : Data size = 590
# Y261  : Data size = 56
# Message published successfully. Data Size: 646
#
# ################ T263 ################
#
# ### Unix Timestamp : 1634307329 ###
# X263  : Data size = 641
# Y262  : Data size = 46
# Message published successfully. Data Size: 687
#
# ################ T264 ################
#
# ### Unix Timestamp : 1634307339 ###
# X264  : Data size = 608
# Y263  : Data size = 51
# Message published successfully. Data Size: 659
#
# ################ T265 ################
#
# ### Unix Timestamp : 1634307349 ###
# X265  : Data size = 572
# Y264  : Data size = 50
# Message published successfully. Data Size: 622
#
# ################ T266 ################
#
# ### Unix Timestamp : 1634307359 ###
# X266  : Data size = 644
# Y265  : Data size = 53
# Message published successfully. Data Size: 697
#
# ################ T267 ################
#
# ### Unix Timestamp : 1634307369 ###
# X267  : Data size = 581
# Y266  : Data size = 53
# Message published successfully. Data Size: 634
#
# ################ T268 ################
#
# ### Unix Timestamp : 1634307379 ###
# X268  : Data size = 547
# Y267  : Data size = 44
# Message published successfully. Data Size: 591
#
# ################ T269 ################
#
# ### Unix Timestamp : 1634307389 ###
# X269  : Data size = 591
# Y268  : Data size = 53
# Message published successfully. Data Size: 644
#
# ################ T270 ################
#
# ### Unix Timestamp : 1634307399 ###
# X270  : Data size = 632
# Y269  : Data size = 59
# Message published successfully. Data Size: 691
#
# ################ T271 ################
#
# ### Unix Timestamp : 1634307409 ###
# X271  : Data size = 605
# Y270  : Data size = 55
# Message published successfully. Data Size: 660
#
# ################ T272 ################
#
# ### Unix Timestamp : 1634307419 ###
# X272  : Data size = 613
# Y271  : Data size = 59
# Message published successfully. Data Size: 672
#
# ################ T273 ################
#
# ### Unix Timestamp : 1634307429 ###
# X273  : Data size = 590
# Y272  : Data size = 54
# Message published successfully. Data Size: 644
#
# ################ T274 ################
#
# ### Unix Timestamp : 1634307439 ###
# X274  : Data size = 646
# Y273  : Data size = 44
# Message published successfully. Data Size: 690
#
# ################ T275 ################
#
# ### Unix Timestamp : 1634307449 ###
# X275  : Data size = 576
# Y274  : Data size = 65
# Message published successfully. Data Size: 641
#
# ################ T276 ################
#
# ### Unix Timestamp : 1634307460 ###
# X276  : Data size = 573
# Y275  : Data size = 59
# Message published successfully. Data Size: 632
#
# ################ T277 ################
#
# ### Unix Timestamp : 1634307470 ###
# X277  : Data size = 589
# Y276  : Data size = 51
# Message published successfully. Data Size: 640
#
# ################ T278 ################
#
# ### Unix Timestamp : 1634307480 ###
# X278  : Data size = 588
# Y277  : Data size = 49
# Message published successfully. Data Size: 637
#
# ################ T279 ################
#
# ### Unix Timestamp : 1634307490 ###
# X279  : Data size = 583
# Y278  : Data size = 57
# Message published successfully. Data Size: 640
#
# ################ T280 ################
#
# ### Unix Timestamp : 1634307500 ###
# X280  : Data size = 612
# Y279  : Data size = 56
# Message published successfully. Data Size: 668
#
# ################ T281 ################
#
# ### Unix Timestamp : 1634307510 ###
# X281  : Data size = 627
# Y280  : Data size = 56
# Message published successfully. Data Size: 683
#
# ################ T282 ################
#
# ### Unix Timestamp : 1634307520 ###
# X282  : Data size = 613
# Y281  : Data size = 47
# Message published successfully. Data Size: 660
#
# ################ T283 ################
#
# ### Unix Timestamp : 1634307530 ###
# X283  : Data size = 619
# Y282  : Data size = 54
# ...
# Message published successfully. Data Size: 647
#
# ################ T1153 ################
#
# ### Unix Timestamp : 1634316283 ###
# X1153  : Data size = 634
# Y1152  : Data size = 53
# Message published successfully. Data Size: 687
#
# ################ T1154 ################
#
# ### Unix Timestamp : 1634316294 ###
# X1154  : Data size = 579
# Y1153  : Data size = 52
# Message published successfully. Data Size: 631
#
# ################ T1155 ################
#
# ### Unix Timestamp : 1634316304 ###
# X1155  : Data size = 606
# Y1154  : Data size = 55
# Message published successfully. Data Size: 661
#
# ################ T1156 ################
#
# ### Unix Timestamp : 1634316314 ###
# X1156  : Data size = 538
# Y1155  : Data size = 50
# Message published successfully. Data Size: 588
#
# ################ T1157 ################
#
# ### Unix Timestamp : 1634316324 ###
# X1157  : Data size = 598
# Y1156  : Data size = 53
# Message published successfully. Data Size: 651
#
# ################ T1158 ################
#
# ### Unix Timestamp : 1634316334 ###
# X1158  : Data size = 587
# Y1157  : Data size = 51
# Message published successfully. Data Size: 638
#
# ################ T1159 ################
#
# ### Unix Timestamp : 1634316344 ###
# X1159  : Data size = 613
# Y1158  : Data size = 48
# Message published successfully. Data Size: 661
#
# ################ T1160 ################
#
# ### Unix Timestamp : 1634316354 ###
# X1160  : Data size = 572
# Y1159  : Data size = 52
# Message published successfully. Data Size: 624
#
# ################ T1161 ################
#
# ### Unix Timestamp : 1634316364 ###
# X1161  : Data size = 570
# Y1160  : Data size = 52
# Message published successfully. Data Size: 622
#
# ################ T1162 ################
#
# ### Unix Timestamp : 1634316374 ###
# X1162  : Data size = 627
# Y1161  : Data size = 53
# Message published successfully. Data Size: 680
#
# ################ T1163 ################
#
# ### Unix Timestamp : 1634316384 ###
# X1163  : Data size = 595
# Y1162  : Data size = 61
# Message published successfully. Data Size: 656
#
# ################ T1164 ################
#
# ### Unix Timestamp : 1634316394 ###
# X1164  : Data size = 570
# Y1163  : Data size = 51
# Message published successfully. Data Size: 621
#
# ################ T1165 ################
#
# ### Unix Timestamp : 1634316404 ###
# X1165  : Data size = 606
# Y1164  : Data size = 56
# Message published successfully. Data Size: 662
#
# ################ T1166 ################
#
# ### Unix Timestamp : 1634316414 ###
# X1166  : Data size = 597
# Y1165  : Data size = 58
# Message published successfully. Data Size: 655
#
# ################ T1167 ################
#
# ### Unix Timestamp : 1634316424 ###
# X1167  : Data size = 617
# Y1166  : Data size = 65
# Message published successfully. Data Size: 682
#
# ################ T1168 ################
#
# ### Unix Timestamp : 1634316434 ###
# X1168  : Data size = 588
# Y1167  : Data size = 56
# Message published successfully. Data Size: 644
#
# ################ T1169 ################
#
# ### Unix Timestamp : 1634316444 ###
# X1169  : Data size = 584
# Y1168  : Data size = 57
# Message published successfully. Data Size: 641
#
# ################ T1170 ################
#
# ### Unix Timestamp : 1634316454 ###
# X1170  : Data size = 630
# Y1169  : Data size = 49
# Message published successfully. Data Size: 679
#
# ################ T1171 ################
#
# ### Unix Timestamp : 1634316464 ###
# X1171  : Data size = 621
# Y1170  : Data size = 56
# Message published successfully. Data Size: 677
#
# ################ T1172 ################
#
# ### Unix Timestamp : 1634316474 ###
# X1172  : Data size = 620
# Y1171  : Data size = 48
# Message published successfully. Data Size: 668
#
# ################ T1173 ################
#
# ### Unix Timestamp : 1634316484 ###
# X1173  : Data size = 636
# Y1172  : Data size = 53
# Message published successfully. Data Size: 689
#
# ################ T1174 ################
#
# ### Unix Timestamp : 1634316495 ###
# X1174  : Data size = 606
# Y1173  : Data size = 50
# Message published successfully. Data Size: 656
#
# ################ T1175 ################
#
# ### Unix Timestamp : 1634316505 ###
# X1175  : Data size = 605
# Y1174  : Data size = 58
# Message published successfully. Data Size: 663
#
# ################ T1176 ################
#
# ### Unix Timestamp : 1634316515 ###
# X1176  : Data size = 582
# Y1175  : Data size = 55
# Message published successfully. Data Size: 637
#
# ################ T1177 ################
#
# ### Unix Timestamp : 1634316525 ###
# X1177  : Data size = 580
# Y1176  : Data size = 62
# Message published successfully. Data Size: 642
#
# ################ T1178 ################
#
# ### Unix Timestamp : 1634316535 ###
# X1178  : Data size = 594
# Y1177  : Data size = 54
# Message published successfully. Data Size: 648
#
# ################ T1179 ################
#
# ### Unix Timestamp : 1634316545 ###
# X1179  : Data size = 608
# Y1178  : Data size = 59
# Message published successfully. Data Size: 667
#
# ################ T1180 ################
#
# ### Unix Timestamp : 1634316555 ###
# X1180  : Data size = 573
# Y1179  : Data size = 47
# Message published successfully. Data Size: 620
#
# ################ T1181 ################
#
# ### Unix Timestamp : 1634316565 ###
# X1181  : Data size = 602
# Y1180  : Data size = 53
# Message published successfully. Data Size: 655
#
# ################ T1182 ################
#
# ### Unix Timestamp : 1634316575 ###
# X1182  : Data size = 617
# Y1181  : Data size = 50
# Message published successfully. Data Size: 667
#
# ################ T1183 ################
#
# ### Unix Timestamp : 1634316585 ###
# X1183  : Data size = 611
# Y1182  : Data size = 47
# Message published successfully. Data Size: 658
#
# ################ T1184 ################
#
# ### Unix Timestamp : 1634316595 ###
# X1184  : Data size = 588
# Y1183  : Data size = 53
# Message published successfully. Data Size: 641
#
# ################ T1185 ################
#
# ### Unix Timestamp : 1634316605 ###
# X1185  : Data size = 538
# Y1184  : Data size = 51
# Message published successfully. Data Size: 589
#
# ################ T1186 ################
#
# ### Unix Timestamp : 1634316615 ###
# X1186  : Data size = 563
# Y1185  : Data size = 52
# Message published successfully. Data Size: 615
#
# ################ T1187 ################
#
# ### Unix Timestamp : 1634316625 ###
# X1187  : Data size = 573
# Y1186  : Data size = 46
# Message published successfully. Data Size: 619
#
# ################ T1188 ################
#
# ### Unix Timestamp : 1634316635 ###
# X1188  : Data size = 593
# Y1187  : Data size = 49
# Message published successfully. Data Size: 642
#
# ################ T1189 ################
#
# ### Unix Timestamp : 1634316645 ###
# X1189  : Data size = 556
# Y1188  : Data size = 49
# Message published successfully. Data Size: 605
#
# ################ T1190 ################
#
# ### Unix Timestamp : 1634316655 ###
# X1190  : Data size = 576
# Y1189  : Data size = 50
# Message published successfully. Data Size: 626
#
# ################ T1191 ################
#
# ### Unix Timestamp : 1634316665 ###
# X1191  : Data size = 563
# Y1190  : Data size = 56
# Message published successfully. Data Size: 619
#
# ################ T1192 ################
#
# ### Unix Timestamp : 1634316675 ###
# X1192  : Data size = 606
# Y1191  : Data size = 46
# Message published successfully. Data Size: 652
#
# ################ T1193 ################
#
# ### Unix Timestamp : 1634316685 ###
# X1193  : Data size = 587
# Y1192  : Data size = 50
# Message published successfully. Data Size: 637
#
# ################ T1194 ################
#
# ### Unix Timestamp : 1634316696 ###
# X1194  : Data size = 620
# Y1193  : Data size = 49
# Message published successfully. Data Size: 669
#
# ################ T1195 ################
#
# ### Unix Timestamp : 1634316706 ###
# X1195  : Data size = 616
# Y1194  : Data size = 51
# Message published successfully. Data Size: 667
#
# ################ T1196 ################
#
# ### Unix Timestamp : 1634316716 ###
# X1196  : Data size = 631
# Y1195  : Data size = 55
# Message published successfully. Data Size: 686
#
# ################ T1197 ################
#
# ### Unix Timestamp : 1634316726 ###
# X1197  : Data size = 586
# Y1196  : Data size = 51
# Message published successfully. Data Size: 637
#
# ################ T1198 ################
#
# ### Unix Timestamp : 1634316736 ###
# X1198  : Data size = 611
# Y1197  : Data size = 52
# Message published successfully. Data Size: 663
#
# ################ T1199 ################
#
# ### Unix Timestamp : 1634316746 ###
# X1199  : Data size = 601
# Y1198  : Data size = 48
# Message published successfully. Data Size: 649
#
# ################ T1200 ################
#
# ### Unix Timestamp : 1634316756 ###
# X1200  : Data size = 563
# Y1199  : Data size = 51
# Message published successfully. Data Size: 614
#
# ################ T1201 ################
#
# ### Unix Timestamp : 1634316766 ###
# X1201  : Data size = 609
# Y1200  : Data size = 54
# Message published successfully. Data Size: 663
#
# ################ T1202 ################
#
# ### Unix Timestamp : 1634316776 ###
# X1202  : Data size = 585
# Y1201  : Data size = 48
# Message published successfully. Data Size: 633
#
# ################ T1203 ################
#
# ### Unix Timestamp : 1634316786 ###
# X1203  : Data size = 606
# Y1202  : Data size = 53
# Message published successfully. Data Size: 659
#
# ################ T1204 ################
#
# ### Unix Timestamp : 1634316796 ###
# X1204  : Data size = 569
# Y1203  : Data size = 51
# Message published successfully. Data Size: 620
#
# ################ T1205 ################
#
# ### Unix Timestamp : 1634316806 ###
# X1205  : Data size = 546
# Y1204  : Data size = 47
# Message published successfully. Data Size: 593
#
# ################ T1206 ################
#
# ### Unix Timestamp : 1634316816 ###
# X1206  : Data size = 568
# Y1205  : Data size = 49
# Message published successfully. Data Size: 617
#
# ################ T1207 ################
#
# ### Unix Timestamp : 1634316826 ###
# X1207  : Data size = 619
# Y1206  : Data size = 45
# Message published successfully. Data Size: 664
#
# ################ T1208 ################
#
# ### Unix Timestamp : 1634316836 ###
# X1208  : Data size = 558
# Y1207  : Data size = 58
# Message published successfully. Data Size: 616
#
# ################ T1209 ################
#
# ### Unix Timestamp : 1634316846 ###
# X1209  : Data size = 614
# Y1208  : Data size = 50
# Message published successfully. Data Size: 664
#
# ################ T1210 ################
#
# ### Unix Timestamp : 1634316856 ###
# X1210  : Data size = 559
# Y1209  : Data size = 53
# Message published successfully. Data Size: 612
#
# ################ T1211 ################
#
# ### Unix Timestamp : 1634316866 ###
# X1211  : Data size = 556
# Y1210  : Data size = 56
# Message published successfully. Data Size: 612
#
# ################ T1212 ################
#
# ### Unix Timestamp : 1634316876 ###
# X1212  : Data size = 580
# Y1211  : Data size = 53
# Message published successfully. Data Size: 633
#
# ################ T1213 ################
#
# ### Unix Timestamp : 1634316886 ###
# X1213  : Data size = 641
# Y1212  : Data size = 56
# Message published successfully. Data Size: 697
#
# ################ T1214 ################
#
# ### Unix Timestamp : 1634316897 ###
# X1214  : Data size = 624
# Y1213  : Data size = 46
# Message published successfully. Data Size: 670
#
# ################ T1215 ################
#
# ### Unix Timestamp : 1634316907 ###
# X1215  : Data size = 648
# Y1214  : Data size = 49
# Message published successfully. Data Size: 697
#
# ################ T1216 ################
#
# ### Unix Timestamp : 1634316917 ###
# X1216  : Data size = 596
# Y1215  : Data size = 58
# Message published successfully. Data Size: 654
#
# ################ T1217 ################
#
# ### Unix Timestamp : 1634316927 ###
# X1217  : Data size = 584
# Y1216  : Data size = 59
# Message published successfully. Data Size: 643
#
# ################ T1218 ################
#
# ### Unix Timestamp : 1634316937 ###
# X1218  : Data size = 565
# Y1217  : Data size = 56
# Message published successfully. Data Size: 621
#
# ################ T1219 ################
#
# ### Unix Timestamp : 1634316947 ###
# X1219  : Data size = 586
# Y1218  : Data size = 57
# Message published successfully. Data Size: 643
#
# ################ T1220 ################
#
# ### Unix Timestamp : 1634316957 ###
# X1220  : Data size = 643
# Y1219  : Data size = 62
# Message published successfully. Data Size: 705
#
# ################ T1221 ################
#
# ### Unix Timestamp : 1634316967 ###
# X1221  : Data size = 583
# Y1220  : Data size = 52
# Message published successfully. Data Size: 635
#
# ################ T1222 ################
#
# ### Unix Timestamp : 1634316977 ###
# X1222  : Data size = 535
# Y1221  : Data size = 57
# Message published successfully. Data Size: 592
#
# ################ T1223 ################
#
# ### Unix Timestamp : 1634316987 ###
# X1223  : Data size = 621
# Y1222  : Data size = 45
# Message published successfully. Data Size: 666
#
# ################ T1224 ################
#
# ### Unix Timestamp : 1634316997 ###
# X1224  : Data size = 560
# Y1223  : Data size = 48
# Message published successfully. Data Size: 608
#
# ################ T1225 ################
#
# ### Unix Timestamp : 1634317007 ###
# X1225  : Data size = 560
# Y1224  : Data size = 55
# Message published successfully. Data Size: 615
#
# ################ T1226 ################
#
# ### Unix Timestamp : 1634317017 ###
# X1226  : Data size = 600
# Y1225  : Data size = 48
# Message published successfully. Data Size: 648
#
# ################ T1227 ################
#
# ### Unix Timestamp : 1634317027 ###
# X1227  : Data size = 594
# Y1226  : Data size = 49
# Message published successfully. Data Size: 643
#
# ################ T1228 ################
#
# ### Unix Timestamp : 1634317037 ###
# X1228  : Data size = 618
# Y1227  : Data size = 53
# Message published successfully. Data Size: 671
#
# ################ T1229 ################
#
# ### Unix Timestamp : 1634317047 ###
# X1229  : Data size = 620
# Y1228  : Data size = 55
# Message published successfully. Data Size: 675
#
# ################ T1230 ################
#
# ### Unix Timestamp : 1634317057 ###
# X1230  : Data size = 561
# Y1229  : Data size = 53
# Message published successfully. Data Size: 614
#
# ################ T1231 ################
#
# ### Unix Timestamp : 1634317067 ###
# X1231  : Data size = 613
# Y1230  : Data size = 59
# Message published successfully. Data Size: 672
#
# ################ T1232 ################
#
# ### Unix Timestamp : 1634317077 ###
# X1232  : Data size = 582
# Y1231  : Data size = 57
# Message published successfully. Data Size: 639
#
# ################ T1233 ################
#
# ### Unix Timestamp : 1634317087 ###
# X1233  : Data size = 568
# Y1232  : Data size = 46
# Message published successfully. Data Size: 614
#
# ################ T1234 ################
#
# ### Unix Timestamp : 1634317098 ###
# X1234  : Data size = 593
# Y1233  : Data size = 48
# Message published successfully. Data Size: 641
#
# ################ T1235 ################
#
# ### Unix Timestamp : 1634317108 ###
# X1235  : Data size = 628
# Y1234  : Data size = 49
# Message published successfully. Data Size: 677
#
# ################ T1236 ################
#
# ### Unix Timestamp : 1634317118 ###
# X1236  : Data size = 610
# Y1235  : Data size = 58
# Message published successfully. Data Size: 668
#
# ################ T1237 ################
#
# ### Unix Timestamp : 1634317128 ###
# X1237  : Data size = 597
# Y1236  : Data size = 57
# Message published successfully. Data Size: 654
#
# ################ T1238 ################
#
# ### Unix Timestamp : 1634317138 ###
# X1238  : Data size = 575
# Y1237  : Data size = 57
# Message published successfully. Data Size: 632
#
# ################ T1239 ################
#
# ### Unix Timestamp : 1634317148 ###
# X1239  : Data size = 601
# Y1238  : Data size = 54
# Message published successfully. Data Size: 655
#
# ################ T1240 ################
#
# ### Unix Timestamp : 1634317158 ###
# X1240  : Data size = 559
# Y1239  : Data size = 56
# Message published successfully. Data Size: 615
#
# ################ T1241 ################
#
# ### Unix Timestamp : 1634317168 ###
# X1241  : Data size = 567
# Y1240  : Data size = 58
# Message published successfully. Data Size: 625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0da5d63a159c> in <module>
#      93                 globals()['B%s' % keyFlight][index]['ts'] = ts
#      94
# ---> 95             sleep(1)
#      96
#      97             ####################################################################################################
#
# KeyboardInterrupt:
